# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 6))
df.plot(kind='scatter', y='CSIRO Adjusted Sea Level', x='Year', ax=ax)
# Out:
# <Axes: xlabel='Year', ylabel='CSIRO Adjusted Sea Level'>

# %%
b1, b0, r_2, p_value, std_err = linregress(x=df['Year'], y=df['CSIRO Adjusted Sea Level'])

# %%
linregress(x=df['Year'], y=df['CSIRO Adjusted Sea Level'])
# Out:
# LinregressResult(slope=0.0630445840121348, intercept=-119.06594196773978, rvalue=0.984757131182585, pvalue=3.788696979113155e-102, stderr=0.0009692118713287149, intercept_stderr=1.8869433812425223)

# %%
b1, b0, r_2, p_value, std_err = linregress(x=df['Year'], y=df['CSIRO Adjusted Sea Level'])

fig, ax = plt.subplots(figsize=(15, 6))
df.plot(kind='scatter', y='CSIRO Adjusted Sea Level', x='Year', ax=ax)

future_year = 2050
future_sea_level = b1*future_year+b0

plt.scatter(future_year, future_sea_level, color='red')

x_fit = np.linspace(min(df['Year']), future_year + 1, 100)

y_fit = b1 * x_fit + b0

plt.plot(x_fit, y_fit, label='Line of Best Fit', color='purple')

start_date = 2000

# df_new = df[df['Year'] >= start_date]

b1_1, b0_1, r_2_1, p_value_1, std_err_1 = linregress(x=df[df['Year'] >= start_date]['Year'], y=df[df['Year'] >= start_date]['CSIRO Adjusted Sea Level'])

# fig, ax = plt.subplots(figsize=(15, 6))
df[df['Year'] >= start_date].plot(kind='scatter', y='CSIRO Adjusted Sea Level', x='Year', ax=ax)

future_year_1 = 2050
future_sea_level_1 = b1_1*future_year_1+b0_1

plt.scatter(future_year_1, future_sea_level_1, color='blue')

x_fit_1 = np.linspace(start_date, future_year_1 + 1, 100)

y_fit_1 = b1_1 * x_fit + b0_1

plt.plot(x_fit_1, y_fit_1, label='Line of Best Fit', color='red')

# plt.show()

plt.show()

# %%
start_date = 2000

# df_new = df[df['Year'] >= start_date]

b1, b0, r_2, p_value, std_err = linregress(x=df[df['Year'] >= start_date]['Year'], y=df[df['Year'] >= start_date]['CSIRO Adjusted Sea Level'])

fig, ax = plt.subplots(figsize=(15, 6))
df[df['Year'] >= start_date].plot(kind='scatter', y='CSIRO Adjusted Sea Level', x='Year', ax=ax)

future_year = 2050
future_sea_level = b1*future_year+b0

plt.scatter(future_year, future_sea_level, color='red')

x_fit = np.linspace(start_date, future_year + 1, 100)

y_fit = b1 * x_fit + b0

plt.plot(x_fit, y_fit, label='Line of Best Fit', color='purple')

plt.show()

# %%
df[df['Year'] >= start_date]
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 120  2000                  7.062992           6.791339           7.334646
# 121  2001                  7.287402           7.019685           7.555118
# 122  2002                  7.381890           7.110236           7.653543
# 123  2003                  7.759843           7.484252           8.035433
# 124  2004                  7.740157           7.464567           8.015748
# 125  2005                  7.744094           7.472441           8.015748
# 126  2006                  7.917323           7.645669           8.188976
# 127  2007                  7.996063           7.712598           8.279528
# 128  2008                  8.350394           8.078740           8.622047
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# ...

# %%
b0
# Out:
# -325.7934668059649

# %%
b0_1
# Out:
# -325.7934668059649
